# %% [markdown]
# # PIVOT POINT

# %% [markdown]
# Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.dates as mdates

# %% [markdown]
# Import Data

# %%
df2 = pd.read_csv(r'SBIN.csv')

# %%
df2 = df2[:100]

# %%
def pv(_open, high, low, close, prev_open, prev_close):
    close = (_open + high + low + close) / 4
    _open = (prev_open + prev_close) / 2
    high = max([high, _open, close])
    low = min([low, _open, close])
    pp = (high+low+close)/3
    s1 = 2*pp - high
    r1 = 2*pp - low
    return s1, r1

# %%
prev_close = df2["Close"].iloc[0]
prev_open = df2["Open"].iloc[0]
s = []
r = []
for i in range(0, len(df2)):
    a, b = pv(df2["Open"].iloc[i], df2["High"].iloc[i], df2["Low"].iloc[i], df2["Close"].iloc[i], prev_open, prev_close)
    prev_open = df2["Open"].iloc[i]
    prev_close = df2["Close"].iloc[i]
    s.append(a)
    r.append(b)

# %%
df2["s"] = s
df2["r"] = r

# %%
df2
# Out:
#                    Date    Open    High     Low   Close   Volume           s  \
# 0   2018-03-01 09:15:00  266.30  270.00  265.70  269.40  1778834  265.700000
# 1   2018-03-01 09:30:00  269.30  269.50  268.00  268.60   803071  267.966667
# 2   2018-03-01 09:45:00  268.70  268.80  266.70  267.00   948966  266.683333
# 3   2018-03-01 10:00:00  266.95  267.00  264.55  264.85  1558320  264.308333
# 4   2018-03-01 10:15:00  264.85  265.00  263.80  263.95  1429056  263.500000
# ..                  ...     ...     ...     ...     ...      ...         ...
# 95  2018-03-07 14:15:00  247.65  248.40  247.05  248.30   976116  247.133333
# 96  2018-03-07 14:30:00  248.30  248.40  247.10  247.45   838550  247.141667
# 97  2018-03-07 14:45:00  247.45  248.15  246.35  247.50  1539994  246.425000
# 98  2018-03-07 15:00:00  247.50  247.70  246.25  246.70  1469123  246.291667
# 99  2018-03-07 15:15:00  246.60  247.15  246.10  246.60  3777124  246.091667
#
#              r
# 0   270.000000
# ...

# %%
ohlc= df2[['Date', 'Close', 'High', 'Low','Open']].copy()
f1, ax = plt.subplots(figsize = (40, 20))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.plot(df2['Date'], df2['Close'], label = 'Price Level')
plt.plot(df2['Date'], df2['High'], label = 'Price Level')
plt.plot(df2['Date'], df2['Low'], label = 'Price Level')
plt.plot(df2['Date'], df2['r'], label = 'Resistance One')
plt.plot(df2['Date'], df2['s'], label = 'Support One')
plt.legend(loc=2, prop={'size': 10})
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Close')
# Out:
# Text(0, 0.5, 'Close')

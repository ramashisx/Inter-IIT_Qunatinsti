# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('BANKNIFTY.csv')

# %%
data
# Out:
#                           Date          Open          High           Low  \
# 0    2018-07-02 00:00:00+05:30  26364.449219  26371.599609  26060.599609
# 1    2018-07-03 00:00:00+05:30  26210.099609  26316.099609  26142.000000
# 2    2018-07-04 00:00:00+05:30  26249.250000  26480.500000  26132.900391
# 3    2018-07-05 00:00:00+05:30  26481.550781  26598.449219  26415.199219
# 4    2018-07-06 00:00:00+05:30  26427.550781  26609.849609  26410.000000
# ..                         ...           ...           ...           ...
# 748  2021-07-23 00:00:00+05:30  34748.351562  35088.000000  34404.750000
# 749  2021-07-26 00:00:00+05:30  34947.851562  35138.199219  34669.550781
# 750  2021-07-27 00:00:00+05:30  35029.300781  35186.101562  34713.550781
# 751  2021-07-28 00:00:00+05:30  34839.449219  34841.550781  34115.199219
# 752  2021-07-29 00:00:00+05:30  34740.300781  34778.148438  34495.199219
#
#             Close     Adj Close  Volume
# 0    26230.300781  26230.300781       0
# ...

# %%
Gapup = []
Gapdown = []

for i in range(len(data)-1):
    if(data.Open[i+1] - data.High[i]>0):
        Gapup.append([(data.Open[i+1] - data.High[i])/data.Close[i],data.Date[i+1]])
    elif(data.Low[i]-data.Open[i+1]>0):
        Gapdown.append([(data.Low[i] - data.Open[i+1])/data.Close[i],data.Date[i+1]])

# %%
# Out:
# [[3.975120180887179e-05, '2018-07-05 00:00:00+05:30'],
#  [0.0012266997993564397, '2018-07-09 00:00:00+05:30'],
#  [0.0023679905151890576, '2018-07-10 00:00:00+05:30'],
#  [0.002443711366389148, '2018-07-18 00:00:00+05:30'],
#  [0.001558072978077301, '2018-07-27 00:00:00+05:30'],
#  [0.0038574967384189755, '2018-07-30 00:00:00+05:30'],
#  [0.0016808066743694823, '2018-08-06 00:00:00+05:30'],
#  [0.0016035663761640995, '2018-08-09 00:00:00+05:30'],
#  [0.0005662133342825516, '2018-08-23 00:00:00+05:30'],
#  [0.0021989085961356537, '2018-08-28 00:00:00+05:30'],
#  [0.0015002488930661844, '2018-09-03 00:00:00+05:30'],
#  [0.006141093826353118, '2018-09-14 00:00:00+05:30'],
#  [0.004664380572989463, '2018-09-26 00:00:00+05:30'],
#  [0.002495551004769184, '2018-10-12 00:00:00+05:30'],
#  [0.005160243540231299, '2018-10-17 00:00:00+05:30'],
#  [0.00822575333250804, '2018-10-22 00:00:00+05:30'],
#  [0.007532285188661818, '2018-10-24 00:00:00+05:30'],
# ...

# %%
x = []
y=[]
for i in Gapup:
    x.append(i[0])
    if(float(i[0])>0.01):
        print((i[1]))
        
for i in Gapdown:
    y.append(i[0])
# Out:
# 2019-05-20 00:00:00+05:30
# 2019-08-26 00:00:00+05:30
# 2019-09-23 00:00:00+05:30
# 2020-03-27 00:00:00+05:30
# 2020-04-15 00:00:00+05:30
# 2020-04-17 00:00:00+05:30
# 2020-04-20 00:00:00+05:30
# 2020-04-28 00:00:00+05:30
# 2020-04-30 00:00:00+05:30
# 2020-05-13 00:00:00+05:30
# 2020-06-01 00:00:00+05:30
# 2020-06-03 00:00:00+05:30
# 2020-06-08 00:00:00+05:30
# 2020-07-20 00:00:00+05:30
# 2020-07-22 00:00:00+05:30
# 2020-08-31 00:00:00+05:30
# 2020-10-19 00:00:00+05:30
# 2020-11-05 00:00:00+05:30
# 2020-11-10 00:00:00+05:30
# 2021-05-18 00:00:00+05:30

# %%
Gapdown = np.array(Gapdown)
Gapdown[(Gapdown>0.01)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/yy/95rx0nm12jqc32p5svcxxv7h0000gn/T/ipykernel_57841/1133740468.py in <module>
#       1 Gapdown = np.array(Gapdown)
# ----> 2 Gapdown[(Gapdown>0.01 and Gapdown<0.015)]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
for i in range(len(y)):
    if(y[i]>0.02):
        y[i] =0.021

for i in range(len(x)):
    if(x[i]>0.02):
        x[i] =0.021
        


fig, ax = plt.subplots(1, 1)

y=np.array(y)
ax.hist(x,color='g',rwidth=0.5,orientation='horizontal',bins=4,label=['okay','s','r','ww'])
ax.hist(-y,color='r',rwidth=0.5,orientation='horizontal',bins=4,label='notokay')

rects = ax.patches
labels = ['0.02+','0.015 - 0.02','0.01 - 0.015','0.005 - 0.01','0.0 - 0.01','0.015 - 0.02','0.01 - 0.015','0.005 - 0.01','0.0 - 0.01']

for rect, label in zip(rects, labels):
#     height = 
    ax.text(rect.get_width(),rect.get_height(), label)


plt.show()

# %%
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX
